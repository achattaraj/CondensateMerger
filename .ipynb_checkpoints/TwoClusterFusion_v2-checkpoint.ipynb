# %% [markdown]
# ## Fusion of two clusters each containing 200 chains. Each cluster is colored differently for visual clarity. Es = 3kT, Ens = 0.5kT
#
#
# <img src="./Two_cluster_fusion_S10N03/S10N03_Fusion_Combo_traj_Run1.mp4" width="500" align="center">

# %%
import numpy as np
import matplotlib.pyplot as plt

file1 = "./Two_cluster_fusion_S3Ns05kT/Mean_CVtrajectory.txt"

d = np.loadtxt(file1)

plt.plot(d[:,0], d[:,1], lw=2)
plt.fill_between(d[:,0], d[:,1]-d[:,2], d[:,1]+d[:,2], alpha=0.3)
#plt.ylim(80,180)
plt.ylabel('R$_{dist}$')
plt.xlabel('Time ($\mu$s)')
plt.xticks([0,5,10,15])
plt.yticks([0,0.5,1,1.5])
plt.show()
